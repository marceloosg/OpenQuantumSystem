# %%
import sys
sys.path.append("./lib")

# %%
from lib.krotov import Krotov
import lib.params as p
import numpy as np

# %%
#target = np.array([[0.4, 0], [0, 0.6]], dtype='complex')
# target[3] = 1/(1+exp(-Bw))

#H = Hamiltonian(gamma=1., omega=2., target=target)
#parameters = p.KrotovParams(eta=1.5, delta=1.5, alpha=0.001, num_t=2000, epsilon=0.01, speedup_factor=2)
#initial_rho = np.array([[0.5, -0.19j], [0.19j, 0.5]], dtype='complex')
times_krotov = 10
from lib.params import KrotovParams
from lib import hamiltonians
p=KrotovParams(num_t=1000)
H=hamiltonians.Hamiltonian(p)
k = Krotov(H, params=p)  #

# %%
k.run_krotov(times_krotov)
# Out:
# Iteration : 1 out of 10
# Iteration : 2 out of 10
# Iteration : 3 out of 10
# Iteration : 4 out of 10
# Iteration : 5 out of 10
# Iteration : 6 out of 10
# Iteration : 7 out of 10
# Iteration : 8 out of 10
# Iteration : 9 out of 10
# Iteration : 10 out of 10

# %%
import matplotlib.pyplot as plt
plt.plot(range(times_krotov), np.array(k.cost), 'r')
# Out:
# /home/marcelo/projects/upwork/Open-Quantum-Systems/venv/lib/python3.7/site-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
plt.plot(range(0,200), np.array(k.fields.control.values[0:200]), 'r')

# %%
plt.plot(k.rho.states[:,[0,3]])
# Out:
# /home/marcelo/projects/upwork/Open-Quantum-Systems/venv/lib/python3.7/site-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# [<matplotlib.lines.Line2D at 0x7fd38f073a90>,
#  <matplotlib.lines.Line2D at 0x7fd38f073c90>]

# %%
plt.plot(np.real(k.rho.states[:,[1,2]]))
# Out:
# [<matplotlib.lines.Line2D at 0x7fd38ed49110>,
#  <matplotlib.lines.Line2D at 0x7fd38ecf29d0>]

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-02f3d7893a94> in <module>()
# ----> 1 np.concatenate(k.rho.states[:,[0,3]],k.rho.states[:,[1,2]],axis=1)
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# TypeError: concatenate() got multiple values for argument 'axis'
